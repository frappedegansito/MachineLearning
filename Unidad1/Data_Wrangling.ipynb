# %% [markdown]
# <a href="https://colab.research.google.com/github/frappedegansito/MachineLearning/blob/main/Unidad1/Data_Wrangling.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib as plt
from matplotlib import pyplot
import numpy as np

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
#ID del archivo
# https://drive.google.com/file/d/1IeKgT2ucz1QQh5qyrktNQKA2xdbR-MNw/view?usp=drive_link
file_id = "1IeKgT2ucz1QQh5qyrktNQKA2xdbR-MNw"

#URL de descarga directa
url = f"https://drive.google.com/uc?id={file_id}"

#Leer el archivo
autos = pd.read_csv(url)
# Out:
# ---------------------------------------------------------------------------
# ParserError                               Traceback (most recent call last)
# /tmp/ipython-input-4232374487.py in <cell line: 0>()
#       7
#       8 #Leer el archivo
# ----> 9 autos = pd.read_csv(url)
#      10
#
# /usr/local/lib/python3.12/dist-packages/pandas/io/parsers/readers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
# ...

# %%
autos.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 522 entries, 0 to 521
# Data columns (total 1 columns):
# ...

# %%
autos.replace("?",np.nan,inplace=True)
autos.head(10)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-2065606026.py in <cell line: 0>()
# ----> 1 autos.replace("?",np.nan,inplace=True)
#       2 autos.head(10)
#
# NameError: name 'autos' is not defined

# %%
autos.replace("?",np.nan,inplace=True)
autos.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-3540168353.py in <cell line: 0>()
# ----> 1 autos.replace("?",np.nan,inplace=True)
#       2 autos.head()
#
# NameError: name 'autos' is not defined

# %%
autos.isna().sum().sort_values()
